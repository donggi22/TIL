# %%
# 양의 정수 n의 팩토리얼 구하기

def factorial(n: int) -> int:
    """양의 정수 n의 팩토리얼값을 재귀적으로 구함"""
    if n > 1:
        return n * factorial(n - 1)
    else:
        return 1

if __name__ == '__main__':
    n = int(input('출력할 팩토리얼값을 입력하세요.: '))
    print(f'{n}의 팩토리얼은 {factorial(n)}입니다.')
# Out:
# 1의 팩토리얼은 1입니다.

# %%
# 유클리드 호제법으로 최대 공약수 구하기

def gcd(x: int, y: int) -> int:
    if y == 0:
        return x
    else:
        return gcd(y, x % y)
    
if __name__ == '__main__':
    print('두 정숫값의 최대 공약수를 구합니다.')

x = int(input('첫번째 정숫값을 입력하세요.: '))
y = int(input('두번째 정숫값을 입력하세요.: '))

print(f'두 정숫값의 최대 공약수(gcd({x}, {y}))는 {gcd(x, y)}입니다.')
# Out:
# 두 정숫값의 최대 공약수를 구합니다.
# 두 정숫값의 최대 공약수(gcd(8, 22))는 2입니다.

# %%
# 피보나치 수열 구하기

def fibonacci(n: int) -> int:
    if n <= 1:
        return 1
    return fibonacci(n - 1) + fibonacci(n - 2)

n = int(input('구하고 싶은 피보나치 수열의 항 번호를 입력하세요: '))

print(f'{n + 1}번째 피보나치 수열의 항은 {fibonacci(n)}입니다.')
# Out:
# 8번째 피보나치 수열의 항은 21입니다.

# %%
# 순수한 재귀 함수 구현하기

def recur(n: int) -> int:
    """순수한 재귀 함수 recur의 구현"""
    if n > 0:
        recur(n - 1)
        print(n)
        recur(n - 2)

x = int(input('정수값을 입력하세요.: '))

recur(x)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2
# 5
# 1
# 2
# 3
# 1

# %%
# recur() 함수의 재귀 호출을 거꾸로 출력하기

def recur(n: int) -> int:
    """순수한 재귀 함수 recur의 구현(거꾸로 출력)"""
    if n > 0:
        recur(n - 2)
        print(n)
        recur(n - 1)

x = int(input('정수값을 입력하세요.: '))

recur(x)
# Out:
# 1
# 3
# 2
# 1
# 5
# 2
# 1
# 4
# 1
# 3
# 2
# 1

# %%
# 부분적으로 꼬리 재귀를 제거한 재귀 함수 구현하기(꼬리 재귀를 제거)

def recur(n: int) -> int:
    """꼬리 재귀를 제거한 recur() 함수"""
    while n > 0:
        recur(n - 1)
        print(n)
        n = n - 2

x = int(input('정수값을 입력하세요.: '))

recur(x)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2
# 5
# 1
# 2
# 3
# 1

# %%
def recur(n: int) -> int:
    """꼬리 재귀를 제거한 recur() 함수"""
    if n > 0:
        recur(n - 1)
        print(n)
        n = n - 2
        
    # 여기부터 recur(n-2)
    while n > 0:
        recur(n - 1)
        print(n)
        n = n - 2

x = int(input('정수값을 입력하세요.: '))

recur(x)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2
# 5
# 1
# 2
# 3
# 1

# %%
def recur(n: int) -> int:
    """꼬리 재귀를 제거한 recur() 함수"""
    while n > 0:
        recur(n - 1)
        print(n)
        n = n - 2

x = int(input('정수값을 입력하세요.: '))

# recur(x)

# 아래 세 줄은 위 recur(x)과 결과가 같음
recur(x - 1)
print(x)
recur(x - 2)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2
# 5
# 1
# 2
# 3
# 1

# %%
# while loop를 for loop로 표현

def recur(x: int) -> int:
    """순수한 재귀 함수 recur의 구현"""
    for n in range(x, 0, -2):
        recur(n - 1)
        print(n)

x = int(input('정수값을 입력하세요.: '))

recur(x)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2
# 5
# 1
# 2
# 3
# 1

# %% [markdown]
# ```py
# def recur(n: int) -> int:
#     """꼬리 재귀를 제거한 recur() 함수"""
#     while n > 0:
#         recur(n - 1)
#         print(n)
#         n = n - 2
# ```
#
# 위의 함수(`recur(n)`)를 수식(`R(n)`)으로 풀어쓰면 (점화식)
#
# <br>
#
# $$
# \begin{aligned}
# R(n)
# & = R(n-1) + [n] \\
# & + R(n-3) + [n-2] \\
# & + R(n-5) + [n-4] \\
# & + R(n-7) + [n-6] \\
# & + \cdots \\
# \\
# & = R(n-1) + [n] \\
# & + R(n-3) + [n-2] \\
# & + R(n-5) + [n-4] \\
# & + R(n-6)\\
# & (\because\; R(n-6)=R(n-7)+[n-6]+\cdots)\\
# \\
# & = R(n-1) + [n] \\
# & + R(n-3) + [n-2] \\
# & + R(n-4) \\
# & (\because\; R(n-4)=R(n-5)+[n-4]+R(n-6))\\
# \\
# & = R(n-1) + [n] \\
# & + R(n-2) \\
# & (\because\; R(n-2)=R(n-3)+[n-2]+R(n-4))\\
# \\
# \end{aligned}
# $$
#
# $$
# R(n)=
# \begin{cases}
# [\;] & n \le 0 \\\\
# R(n-1) + [n] + R(n-2) & n > 0
# \end{cases}
# $$

# %%
def recur(n):
    if n <= 0:
        return []
    return recur(n-1) + [n] + recur(n-2)

n = 5

lst = recur(n)
for num in lst:
    print(num)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2
# 5
# 1
# 2
# 3
# 1

# %%
def recur(n: int) -> int:
    """순수한 재귀 함수 recur의 구현"""
    if n > 0:
        recur(n - 1)
        print(n)
        recur(n - 2)
        recur(n - 3)
        recur(n - 4)

x = int(input('정수값을 입력하세요.: '))

recur(x)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2
# 1

# %%
def recur(n: int) -> int:
    """순수한 재귀 함수 recur의 구현"""
    while n > 0:
        recur(n - 1)
        print(n)
        recur(n - 2)
        recur(n - 3)
        n = n - 4

x = int(input('정수값을 입력하세요.: '))

recur(x)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2
# 1

# %%
# 고정 길이 스택 클래스(collections.deque을 사용)

from typing import Any
from collections import deque

class Stack:
    """고정 길이 스택 클래스(collections.deque을 사용)"""

    def __init__(self, maxlen: int = 256) -> None:
        """초기화"""
        self.capacity = maxlen
        self.__stk = deque([], maxlen)

    def __len__(self) -> int:
        """스택에 쌓여있는 데이터 개수를 반환"""
        return len(self.__stk)

    def is_empty(self) -> bool:
        """스택이 비어 있습니까?"""
        return not self.__stk

    def is_full(self) -> bool:
        """스택이 가득 찼습니까?"""
        return len(self.__stk) == self.__stk.maxlen

    def push(self, value: Any) -> None:
        """스택에 value를 푸시"""
        self.__stk.append(value)

    def pop(self) -> Any:
        """스택에서 데이터를 팝(꼭대기의 데이터를 꺼냄)"""
        return self.__stk.pop()

    def peek(self) -> Any:
        """스택에서 데이터를 피크(꼭대기의 데이터를 들여다 봄)"""
        return self.__stk[-1]

    def clear(self) -> None:
        """스택을 비움(모든 데이터를 삭제)"""
        self.__stk.clear()

    def find(self, value: Any) -> Any:
        """스택에서 value를 찾아 첨자(없으면 -1)를 반환"""
        try:
            return self.__stk.index(value)
        except ValueError:
            return -1

    def count(self, value: Any) -> int:
        """스택에 포함된 value의 개수를 반환"""
        return self.__stk.count(value)

    def __contains__(self, value: Any) -> bool:
        """스택에 value가 포함되어 있는가?"""
        return self.count(value)

    def dump(self) -> int:
        """덤프(스택 안의 모든 데이터를 바닥 → 꼭대기 순서로 출력)"""
        print(list(self.__stk))

# %%
# 스택으로 재귀 함수 구현하기(재귀를 제거)

def recur(n: int) -> int:
    """재귀를 제거한 recur() 함수"""
    s = Stack(n)

    while True:
        if n > 0:
            s.push(n) # n값을 푸시
            n = n - 1
            continue
        if not s.is_empty(): # 스택이 비어 있지 않으면
            n = s.pop() # 저장한 값을 n에 팝
            print(n)
            n = n - 2
            continue
        break

x = int(input('정숫값을 입력하세요.: '))

recur(x)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2
# 5
# 1
# 2
# 3
# 1

# %% [markdown]
# 기저 조건이 있는 재귀는
# \
# call stack을 사용하는 알고리즘이고,
# \
# 동일한 상태를 명시적 stack으로 1:1 치환할 수 있다.
# \
# 기저가 없으면 둘 다 무한히 쌓이다가 터진다.
#
# ```py
# recur(5)
#  └─ recur(4)
#      └─ recur(3)
#          └─ recur(2)
#              └─ recur(1)
#                  └─ recur(0)       # 종료
#                     print(1)                   # 1 출력
#                     recur(-1)      # 종료
#                 print(2)                       # 2 출력
#                 recur(0)           # 종료
#             print(3)                           # 3 출력
#             recur(1)
#              └─ recur(0)           # 종료
#                 print(1)                       # 1 출력
#                 recur(-1)          # 종료
#         print(4)                               # 4 출력
#         recur(2)
#              └─ recur(1)
#                  └─ recur(0)       # 종료
#                     print(1)                   # 1 출력
#                     recur(-1)      # 종료
#                 print(2)                       # 2 출력
#                 recur(0)           # 종료
#     print(5)                                   # 5 출력
#     recur(3)
#          └─ recur(2)
#              └─ recur(1)
#                  └─ recur(0)       # 종료
#                     print(1)                   # 1 출력
#                     recur(-1)      # 종료
#                 print(2)                       # 2 출력
#                 recur(0)           # 종료
#             print(3)                           # 3 출력
#             recur(1)
#                  └─ recur(0)       # 종료
#                     print(1)                   # 1 출력
#                     recur(-1)      # 종료
# ```

# %%
recur(1)
# Out:
# 1

# %%
recur(2)
# Out:
# 1
# 2

# %%
recur(3)
# Out:
# 1
# 2
# 3
# 1

# %%
recur(4)
# Out:
# 1
# 2
# 3
# 1
# 4
# 1
# 2

# %%
# 하노이 탑 구현하기

import time

def move(no: int, x: int, y: int) -> None:
    """원반 no개를 x기둥에서 y기둥으로 옮김"""

    if no > 1:
        move(no - 1, x, 6 - x - y) # x: 첫번째 기둥(시작), y: 세번째 기둥(목표), 6 - x - y: 두번째 기둥(경유)
    
    print(f'원반 [{no}]을(를) {x}기둥에서 {y}기둥으로 옮깁니다.')
    
    if no > 1:
        move(no - 1, 6 - x - y, y)
    

print('하노이의 탑을 구현합니다.')
n = int(input('원반의 개수를 입력하세요.: '))

move(n, 1, 3) # 1 기둥에 쌓인 원반 n개를 3기둥으로 옮김
# Out:
# 하노이의 탑을 구현합니다.
# 원반 [1]을(를) 1기둥에서 3기둥으로 옮깁니다.
# 원반 [2]을(를) 1기둥에서 2기둥으로 옮깁니다.
# 원반 [1]을(를) 3기둥에서 2기둥으로 옮깁니다.
# 원반 [3]을(를) 1기둥에서 3기둥으로 옮깁니다.
# 원반 [1]을(를) 2기둥에서 1기둥으로 옮깁니다.
# 원반 [2]을(를) 2기둥에서 3기둥으로 옮깁니다.
# 원반 [1]을(를) 1기둥에서 3기둥으로 옮깁니다.

# %%
def move(no: int, x:int, y:int) -> None:
    """원반 no개를 x기둥에서 y기둥으로 옮김"""
    s = []
    while True:
        if no > 0:
            s.append([no, x, y])
            no = no - 1
            y = 6 - x - y
            continue
        
        if len(s):
            no, x, y = s.pop()
            print(f'원반 [{no}]을(를) {x}기둥에서 {y}기둥으로 옮깁니다.')
            no = no - 1
            x = 6 - x - y
            continue
        break

print('하노이의 탑을 구현합니다.')
n = int(input('원반의 개수를 입력하세요.: '))

move(n, 1, 3) # 1 기둥에 쌓인 원반 n개를 3기둥으로 옮김
# Out:
# 하노이의 탑을 구현합니다.
# 원반 [1]을(를) 1기둥에서 3기둥으로 옮깁니다.
# 원반 [2]을(를) 1기둥에서 2기둥으로 옮깁니다.
# 원반 [1]을(를) 3기둥에서 2기둥으로 옮깁니다.
# 원반 [3]을(를) 1기둥에서 3기둥으로 옮깁니다.
# 원반 [1]을(를) 2기둥에서 1기둥으로 옮깁니다.
# 원반 [2]을(를) 2기둥에서 3기둥으로 옮깁니다.
# 원반 [1]을(를) 1기둥에서 3기둥으로 옮깁니다.
