# %%
from sklearn.datasets import make_classification

x, t = make_classification(
    n_samples=1000,
    n_features=20,
    n_informative=2,
    n_redundant=0,
    n_classes=2,
    random_state=0
)

x.shape, t.shape
# Out:
# ((1000, 20), (1000,))

# %%
import numpy as np
import matplotlib.pyplot as plt
from optimizer import SGD
from sklearn.datasets import make_classification
from two_layer_net import TwoLayerNet

# 하이퍼 파라미터 설정
max_epoch = 100
batch_size = 30
hidden_size = 10
learning_rate = 1.0

# 데이터 읽기, 모델과 옵티마이저 생성
x, t = make_classification(
    n_samples=1000,
    n_features=20,
    n_informative=2,
    n_redundant=0,
    n_classes=2,
    random_state=0
)

model = TwoLayerNet(input_size=20, hidden_size=hidden_size, output_size=2)
optimizer = SGD(lr=learning_rate)

# 학습에 사용하는 변수
data_size = len(x)
max_iters = data_size // batch_size
total_loss = 0
loss_count = 0
loss_list = []

for epoch in range(max_epoch):
    # 데이터 뒤섞기
    idx = np.random.permutation(data_size)
    x = x[idx]
    t = t[idx]

    for iters in range(max_iters):
        batch_x = x[iters*batch_size:(iters+1)*batch_size]
        batch_t = t[iters*batch_size:(iters+1)*batch_size]

        # 기울기를 구해 매개변수 갱신
        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)

        total_loss += loss
        loss_count += 1

        # 정기적으로 학습 결과 출력
        if (iters+1) % 10 == 0:
            avg_loss = total_loss / loss_count
            print('| 에폭 %d | 반복 %d / %d | 손실 %.2f' %(epoch+1, iters+1, max_iters, avg_loss))
            loss_list.append(avg_loss)
            total_loss, loss_count = 0, 0
# Out:
# | 에폭 1 | 반복 10 / 33 | 손실 0.72
# | 에폭 1 | 반복 20 / 33 | 손실 0.68
# | 에폭 1 | 반복 30 / 33 | 손실 0.53
# | 에폭 2 | 반복 10 / 33 | 손실 0.26
# | 에폭 2 | 반복 20 / 33 | 손실 0.22
# | 에폭 2 | 반복 30 / 33 | 손실 0.16
# | 에폭 3 | 반복 10 / 33 | 손실 0.17
# | 에폭 3 | 반복 20 / 33 | 손실 0.19
# | 에폭 3 | 반복 30 / 33 | 손실 0.18
# | 에폭 4 | 반복 10 / 33 | 손실 0.15
# | 에폭 4 | 반복 20 / 33 | 손실 0.15
# | 에폭 4 | 반복 30 / 33 | 손실 0.18
# | 에폭 5 | 반복 10 / 33 | 손실 0.17
# | 에폭 5 | 반복 20 / 33 | 손실 0.18
# | 에폭 5 | 반복 30 / 33 | 손실 0.16
# | 에폭 6 | 반복 10 / 33 | 손실 0.19
# | 에폭 6 | 반복 20 / 33 | 손실 0.16
# | 에폭 6 | 반복 30 / 33 | 손실 0.14
# | 에폭 7 | 반복 10 / 33 | 손실 0.16
# | 에폭 7 | 반복 20 / 33 | 손실 0.17
# | 에폭 7 | 반복 30 / 33 | 손실 0.12
# | 에폭 8 | 반복 10 / 33 | 손실 0.14
# | 에폭 8 | 반복 20 / 33 | 손실 0.18
# | 에폭 8 | 반복 30 / 33 | 손실 0.11
# | 에폭 9 | 반복 10 / 33 | 손실 0.14
# | 에폭 9 | 반복 20 / 33 | 손실 0.10
# | 에폭 9 | 반복 30 / 33 | 손실 0.16
# | 에폭 10 | 반복 10 / 33 | 손실 0.13
# | 에폭 10 | 반복 20 / 33 | 손실 0.12
# | 에폭 10 | 반복 30 / 33 | 손실 0.16
# | 에폭 11 | 반복 10 / 33 | 손실 0.13
# | 에폭 11 | 반복 20 / 33 | 손실 0.10
# | 에폭 11 | 반복 30 / 33 | 손실 0.14
# | 에폭 12 | 반복 10 / 33 | 손실 0.15
# | 에폭 12 | 반복 20 / 33 | 손실 0.13
# | 에폭 12 | 반복 30 / 33 | 손실 0.12
# | 에폭 13 | 반복 10 / 33 | 손실 0.11
# | 에폭 13 | 반복 20 / 33 | 손실 0.13
# | 에폭 13 | 반복 30 / 33 | 손실 0.12
# | 에폭 14 | 반복 10 / 33 | 손실 0.12
# | 에폭 14 | 반복 20 / 33 | 손실 0.11
# | 에폭 14 | 반복 30 / 33 | 손실 0.13
# | 에폭 15 | 반복 10 / 33 | 손실 0.10
# | 에폭 15 | 반복 20 / 33 | 손실 0.08
# | 에폭 15 | 반복 30 / 33 | 손실 0.17
# | 에폭 16 | 반복 10 / 33 | 손실 0.11
# | 에폭 16 | 반복 20 / 33 | 손실 0.10
# | 에폭 16 | 반복 30 / 33 | 손실 0.12
# | 에폭 17 | 반복 10 / 33 | 손실 0.11
# | 에폭 17 | 반복 20 / 33 | 손실 0.11
# | 에폭 17 | 반복 30 / 33 | 손실 0.13
# | 에폭 18 | 반복 10 / 33 | 손실 0.12
# | 에폭 18 | 반복 20 / 33 | 손실 0.11
# | 에폭 18 | 반복 30 / 33 | 손실 0.09
# | 에폭 19 | 반복 10 / 33 | 손실 0.10
# | 에폭 19 | 반복 20 / 33 | 손실 0.12
# | 에폭 19 | 반복 30 / 33 | 손실 0.12
# | 에폭 20 | 반복 10 / 33 | 손실 0.10
# | 에폭 20 | 반복 20 / 33 | 손실 0.09
# | 에폭 20 | 반복 30 / 33 | 손실 0.11
# | 에폭 21 | 반복 10 / 33 | 손실 0.09
# | 에폭 21 | 반복 20 / 33 | 손실 0.09
# | 에폭 21 | 반복 30 / 33 | 손실 0.14
# | 에폭 22 | 반복 10 / 33 | 손실 0.08
# | 에폭 22 | 반복 20 / 33 | 손실 0.09
# | 에폭 22 | 반복 30 / 33 | 손실 0.15
# | 에폭 23 | 반복 10 / 33 | 손실 0.08
# | 에폭 23 | 반복 20 / 33 | 손실 0.09
# | 에폭 23 | 반복 30 / 33 | 손실 0.14
# | 에폭 24 | 반복 10 / 33 | 손실 0.08
# | 에폭 24 | 반복 20 / 33 | 손실 0.12
# | 에폭 24 | 반복 30 / 33 | 손실 0.11
# | 에폭 25 | 반복 10 / 33 | 손실 0.09
# | 에폭 25 | 반복 20 / 33 | 손실 0.09
# | 에폭 25 | 반복 30 / 33 | 손실 0.11
# | 에폭 26 | 반복 10 / 33 | 손실 0.09
# | 에폭 26 | 반복 20 / 33 | 손실 0.11
# | 에폭 26 | 반복 30 / 33 | 손실 0.09
# | 에폭 27 | 반복 10 / 33 | 손실 0.09
# | 에폭 27 | 반복 20 / 33 | 손실 0.09
# | 에폭 27 | 반복 30 / 33 | 손실 0.11
# | 에폭 28 | 반복 10 / 33 | 손실 0.07
# | 에폭 28 | 반복 20 / 33 | 손실 0.10
# | 에폭 28 | 반복 30 / 33 | 손실 0.10
# | 에폭 29 | 반복 10 / 33 | 손실 0.07
# | 에폭 29 | 반복 20 / 33 | 손실 0.10
# | 에폭 29 | 반복 30 / 33 | 손실 0.10
# | 에폭 30 | 반복 10 / 33 | 손실 0.10
# | 에폭 30 | 반복 20 / 33 | 손실 0.08
# | 에폭 30 | 반복 30 / 33 | 손실 0.08
# | 에폭 31 | 반복 10 / 33 | 손실 0.06
# | 에폭 31 | 반복 20 / 33 | 손실 0.09
# | 에폭 31 | 반복 30 / 33 | 손실 0.11
# | 에폭 32 | 반복 10 / 33 | 손실 0.07
# | 에폭 32 | 반복 20 / 33 | 손실 0.09
# | 에폭 32 | 반복 30 / 33 | 손실 0.06
# | 에폭 33 | 반복 10 / 33 | 손실 0.07
# | 에폭 33 | 반복 20 / 33 | 손실 0.10
# | 에폭 33 | 반복 30 / 33 | 손실 0.07
# | 에폭 34 | 반복 10 / 33 | 손실 0.07
# | 에폭 34 | 반복 20 / 33 | 손실 0.06
# | 에폭 34 | 반복 30 / 33 | 손실 0.09
# | 에폭 35 | 반복 10 / 33 | 손실 0.08
# | 에폭 35 | 반복 20 / 33 | 손실 0.07
# | 에폭 35 | 반복 30 / 33 | 손실 0.07
# | 에폭 36 | 반복 10 / 33 | 손실 0.08
# | 에폭 36 | 반복 20 / 33 | 손실 0.06
# | 에폭 36 | 반복 30 / 33 | 손실 0.07
# | 에폭 37 | 반복 10 / 33 | 손실 0.05
# | 에폭 37 | 반복 20 / 33 | 손실 0.06
# | 에폭 37 | 반복 30 / 33 | 손실 0.07
# | 에폭 38 | 반복 10 / 33 | 손실 0.06
# | 에폭 38 | 반복 20 / 33 | 손실 0.08
# | 에폭 38 | 반복 30 / 33 | 손실 0.07
# | 에폭 39 | 반복 10 / 33 | 손실 0.06
# | 에폭 39 | 반복 20 / 33 | 손실 0.06
# | 에폭 39 | 반복 30 / 33 | 손실 0.06
# | 에폭 40 | 반복 10 / 33 | 손실 0.06
# | 에폭 40 | 반복 20 / 33 | 손실 0.05
# | 에폭 40 | 반복 30 / 33 | 손실 0.08
# | 에폭 41 | 반복 10 / 33 | 손실 0.06
# | 에폭 41 | 반복 20 / 33 | 손실 0.05
# | 에폭 41 | 반복 30 / 33 | 손실 0.06
# | 에폭 42 | 반복 10 / 33 | 손실 0.06
# | 에폭 42 | 반복 20 / 33 | 손실 0.05
# | 에폭 42 | 반복 30 / 33 | 손실 0.06
# | 에폭 43 | 반복 10 / 33 | 손실 0.06
# | 에폭 43 | 반복 20 / 33 | 손실 0.06
# | 에폭 43 | 반복 30 / 33 | 손실 0.05
# | 에폭 44 | 반복 10 / 33 | 손실 0.05
# | 에폭 44 | 반복 20 / 33 | 손실 0.03
# | 에폭 44 | 반복 30 / 33 | 손실 0.07
# | 에폭 45 | 반복 10 / 33 | 손실 0.04
# | 에폭 45 | 반복 20 / 33 | 손실 0.06
# | 에폭 45 | 반복 30 / 33 | 손실 0.05
# | 에폭 46 | 반복 10 / 33 | 손실 0.05
# | 에폭 46 | 반복 20 / 33 | 손실 0.04
# | 에폭 46 | 반복 30 / 33 | 손실 0.06
# | 에폭 47 | 반복 10 / 33 | 손실 0.05
# | 에폭 47 | 반복 20 / 33 | 손실 0.05
# | 에폭 47 | 반복 30 / 33 | 손실 0.04
# | 에폭 48 | 반복 10 / 33 | 손실 0.05
# | 에폭 48 | 반복 20 / 33 | 손실 0.05
# | 에폭 48 | 반복 30 / 33 | 손실 0.04
# | 에폭 49 | 반복 10 / 33 | 손실 0.04
# | 에폭 49 | 반복 20 / 33 | 손실 0.05
# | 에폭 49 | 반복 30 / 33 | 손실 0.04
# | 에폭 50 | 반복 10 / 33 | 손실 0.03
# | 에폭 50 | 반복 20 / 33 | 손실 0.04
# | 에폭 50 | 반복 30 / 33 | 손실 0.05
# | 에폭 51 | 반복 10 / 33 | 손실 0.05
# | 에폭 51 | 반복 20 / 33 | 손실 0.04
# | 에폭 51 | 반복 30 / 33 | 손실 0.04
# | 에폭 52 | 반복 10 / 33 | 손실 0.03
# | 에폭 52 | 반복 20 / 33 | 손실 0.05
# | 에폭 52 | 반복 30 / 33 | 손실 0.04
# | 에폭 53 | 반복 10 / 33 | 손실 0.04
# | 에폭 53 | 반복 20 / 33 | 손실 0.05
# | 에폭 53 | 반복 30 / 33 | 손실 0.04
# | 에폭 54 | 반복 10 / 33 | 손실 0.04
# | 에폭 54 | 반복 20 / 33 | 손실 0.04
# | 에폭 54 | 반복 30 / 33 | 손실 0.04
# | 에폭 55 | 반복 10 / 33 | 손실 0.03
# | 에폭 55 | 반복 20 / 33 | 손실 0.04
# | 에폭 55 | 반복 30 / 33 | 손실 0.03
# | 에폭 56 | 반복 10 / 33 | 손실 0.04
# | 에폭 56 | 반복 20 / 33 | 손실 0.03
# | 에폭 56 | 반복 30 / 33 | 손실 0.05
# | 에폭 57 | 반복 10 / 33 | 손실 0.04
# | 에폭 57 | 반복 20 / 33 | 손실 0.03
# | 에폭 57 | 반복 30 / 33 | 손실 0.04
# | 에폭 58 | 반복 10 / 33 | 손실 0.04
# | 에폭 58 | 반복 20 / 33 | 손실 0.03
# | 에폭 58 | 반복 30 / 33 | 손실 0.03
# | 에폭 59 | 반복 10 / 33 | 손실 0.04
# | 에폭 59 | 반복 20 / 33 | 손실 0.03
# | 에폭 59 | 반복 30 / 33 | 손실 0.03
# | 에폭 60 | 반복 10 / 33 | 손실 0.03
# | 에폭 60 | 반복 20 / 33 | 손실 0.04
# | 에폭 60 | 반복 30 / 33 | 손실 0.03
# | 에폭 61 | 반복 10 / 33 | 손실 0.03
# | 에폭 61 | 반복 20 / 33 | 손실 0.04
# | 에폭 61 | 반복 30 / 33 | 손실 0.03
# | 에폭 62 | 반복 10 / 33 | 손실 0.03
# | 에폭 62 | 반복 20 / 33 | 손실 0.03
# | 에폭 62 | 반복 30 / 33 | 손실 0.04
# | 에폭 63 | 반복 10 / 33 | 손실 0.02
# | 에폭 63 | 반복 20 / 33 | 손실 0.05
# | 에폭 63 | 반복 30 / 33 | 손실 0.03
# | 에폭 64 | 반복 10 / 33 | 손실 0.03
# | 에폭 64 | 반복 20 / 33 | 손실 0.03
# | 에폭 64 | 반복 30 / 33 | 손실 0.03
# | 에폭 65 | 반복 10 / 33 | 손실 0.02
# | 에폭 65 | 반복 20 / 33 | 손실 0.03
# | 에폭 65 | 반복 30 / 33 | 손실 0.03
# | 에폭 66 | 반복 10 / 33 | 손실 0.03
# | 에폭 66 | 반복 20 / 33 | 손실 0.02
# | 에폭 66 | 반복 30 / 33 | 손실 0.03
# | 에폭 67 | 반복 10 / 33 | 손실 0.02
# | 에폭 67 | 반복 20 / 33 | 손실 0.02
# | 에폭 67 | 반복 30 / 33 | 손실 0.04
# | 에폭 68 | 반복 10 / 33 | 손실 0.02
# | 에폭 68 | 반복 20 / 33 | 손실 0.03
# | 에폭 68 | 반복 30 / 33 | 손실 0.03
# | 에폭 69 | 반복 10 / 33 | 손실 0.02
# | 에폭 69 | 반복 20 / 33 | 손실 0.02
# | 에폭 69 | 반복 30 / 33 | 손실 0.02
# | 에폭 70 | 반복 10 / 33 | 손실 0.03
# | 에폭 70 | 반복 20 / 33 | 손실 0.02
# | 에폭 70 | 반복 30 / 33 | 손실 0.03
# | 에폭 71 | 반복 10 / 33 | 손실 0.02
# | 에폭 71 | 반복 20 / 33 | 손실 0.02
# | 에폭 71 | 반복 30 / 33 | 손실 0.03
# | 에폭 72 | 반복 10 / 33 | 손실 0.02
# | 에폭 72 | 반복 20 / 33 | 손실 0.03
# | 에폭 72 | 반복 30 / 33 | 손실 0.02
# | 에폭 73 | 반복 10 / 33 | 손실 0.02
# | 에폭 73 | 반복 20 / 33 | 손실 0.02
# | 에폭 73 | 반복 30 / 33 | 손실 0.02
# | 에폭 74 | 반복 10 / 33 | 손실 0.02
# | 에폭 74 | 반복 20 / 33 | 손실 0.02
# | 에폭 74 | 반복 30 / 33 | 손실 0.02
# | 에폭 75 | 반복 10 / 33 | 손실 0.02
# | 에폭 75 | 반복 20 / 33 | 손실 0.02
# | 에폭 75 | 반복 30 / 33 | 손실 0.02
# | 에폭 76 | 반복 10 / 33 | 손실 0.02
# | 에폭 76 | 반복 20 / 33 | 손실 0.02
# | 에폭 76 | 반복 30 / 33 | 손실 0.02
# | 에폭 77 | 반복 10 / 33 | 손실 0.02
# | 에폭 77 | 반복 20 / 33 | 손실 0.02
# | 에폭 77 | 반복 30 / 33 | 손실 0.02
# | 에폭 78 | 반복 10 / 33 | 손실 0.01
# | 에폭 78 | 반복 20 / 33 | 손실 0.02
# | 에폭 78 | 반복 30 / 33 | 손실 0.02
# | 에폭 79 | 반복 10 / 33 | 손실 0.01
# | 에폭 79 | 반복 20 / 33 | 손실 0.01
# | 에폭 79 | 반복 30 / 33 | 손실 0.02
# | 에폭 80 | 반복 10 / 33 | 손실 0.01
# | 에폭 80 | 반복 20 / 33 | 손실 0.02
# | 에폭 80 | 반복 30 / 33 | 손실 0.02
# | 에폭 81 | 반복 10 / 33 | 손실 0.02
# | 에폭 81 | 반복 20 / 33 | 손실 0.02
# | 에폭 81 | 반복 30 / 33 | 손실 0.02
# | 에폭 82 | 반복 10 / 33 | 손실 0.02
# | 에폭 82 | 반복 20 / 33 | 손실 0.02
# | 에폭 82 | 반복 30 / 33 | 손실 0.01
# | 에폭 83 | 반복 10 / 33 | 손실 0.01
# | 에폭 83 | 반복 20 / 33 | 손실 0.02
# | 에폭 83 | 반복 30 / 33 | 손실 0.01
# | 에폭 84 | 반복 10 / 33 | 손실 0.01
# | 에폭 84 | 반복 20 / 33 | 손실 0.02
# | 에폭 84 | 반복 30 / 33 | 손실 0.01
# | 에폭 85 | 반복 10 / 33 | 손실 0.02
# | 에폭 85 | 반복 20 / 33 | 손실 0.01
# | 에폭 85 | 반복 30 / 33 | 손실 0.02
# | 에폭 86 | 반복 10 / 33 | 손실 0.02
# | 에폭 86 | 반복 20 / 33 | 손실 0.01
# | 에폭 86 | 반복 30 / 33 | 손실 0.01
# | 에폭 87 | 반복 10 / 33 | 손실 0.02
# | 에폭 87 | 반복 20 / 33 | 손실 0.01
# | 에폭 87 | 반복 30 / 33 | 손실 0.01
# | 에폭 88 | 반복 10 / 33 | 손실 0.01
# | 에폭 88 | 반복 20 / 33 | 손실 0.02
# | 에폭 88 | 반복 30 / 33 | 손실 0.01
# | 에폭 89 | 반복 10 / 33 | 손실 0.02
# | 에폭 89 | 반복 20 / 33 | 손실 0.01
# | 에폭 89 | 반복 30 / 33 | 손실 0.01
# | 에폭 90 | 반복 10 / 33 | 손실 0.01
# | 에폭 90 | 반복 20 / 33 | 손실 0.01
# | 에폭 90 | 반복 30 / 33 | 손실 0.01
# | 에폭 91 | 반복 10 / 33 | 손실 0.01
# | 에폭 91 | 반복 20 / 33 | 손실 0.01
# | 에폭 91 | 반복 30 / 33 | 손실 0.02
# | 에폭 92 | 반복 10 / 33 | 손실 0.01
# | 에폭 92 | 반복 20 / 33 | 손실 0.02
# | 에폭 92 | 반복 30 / 33 | 손실 0.01
# | 에폭 93 | 반복 10 / 33 | 손실 0.01
# | 에폭 93 | 반복 20 / 33 | 손실 0.01
# | 에폭 93 | 반복 30 / 33 | 손실 0.01
# | 에폭 94 | 반복 10 / 33 | 손실 0.01
# | 에폭 94 | 반복 20 / 33 | 손실 0.01
# | 에폭 94 | 반복 30 / 33 | 손실 0.01
# | 에폭 95 | 반복 10 / 33 | 손실 0.01
# | 에폭 95 | 반복 20 / 33 | 손실 0.01
# | 에폭 95 | 반복 30 / 33 | 손실 0.01
# | 에폭 96 | 반복 10 / 33 | 손실 0.01
# | 에폭 96 | 반복 20 / 33 | 손실 0.01
# | 에폭 96 | 반복 30 / 33 | 손실 0.01
# | 에폭 97 | 반복 10 / 33 | 손실 0.01
# | 에폭 97 | 반복 20 / 33 | 손실 0.01
# | 에폭 97 | 반복 30 / 33 | 손실 0.01
# | 에폭 98 | 반복 10 / 33 | 손실 0.01
# | 에폭 98 | 반복 20 / 33 | 손실 0.01
# | 에폭 98 | 반복 30 / 33 | 손실 0.01
# | 에폭 99 | 반복 10 / 33 | 손실 0.01
# | 에폭 99 | 반복 20 / 33 | 손실 0.01
# | 에폭 99 | 반복 30 / 33 | 손실 0.01
# | 에폭 100 | 반복 10 / 33 | 손실 0.01
# | 에폭 100 | 반복 20 / 33 | 손실 0.01
# | 에폭 100 | 반복 30 / 33 | 손실 0.01

# %%
from layers import SigmoidWithLoss
criterion = SigmoidWithLoss()
oh_t = np.zeros((len(t), 2), dtype=int)
oh_t[np.arange(t.size), t] = 1
criterion.forward(model.predict(x), oh_t)
# Out:
# 0.08156028821849906
